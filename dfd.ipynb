# %%
duplicated_values_count = len(df[[]].duplicated(subset=[f"column"]))

# %%
import pandas as pd

# %%
task1 = pd.read_csv('data/raw/task_data_1.csv').drop(columns='Unnamed: 0')
task2 = pd.read_csv('data/raw/task_data_2.csv')

# %%
task1
# Out:
#        id      car_brand  car_registration_year  car_eng_pow  customer_age  \
# 0       1    Lamborghini                   1992        141.0          18.0
# 1       2     Volkswagen                   1991        363.0          67.0
# 2       3         Nissan                   2003        460.0          32.0
# 3       4            Kia                   2007        221.0          37.0
# 4       5    Lamborghini                   2009        238.0          22.0
# ..    ...            ...                    ...          ...           ...
# 995   996          Dodge                   2004        412.0          17.0
# 996   997          Lexus                   2010        494.0          18.0
# 997   998       Maserati                   2009        373.0          95.0
# 998   999          Lexus                   2012        398.0          93.0
# 999  1000  Mercedes-Benz                   1997         59.0         100.0
#
#     postal_code  claim_amount policy_id
# ...

# %%
task2
# Out:
#        id  car_brand  car_registration_year  car_eng_pow  customer_age  \
# 0       1      Mazda                   2004         80.0          50.0
# 1       2      Buick                   1997        323.0          54.0
# 2       3    Hyundai                   2003        392.0          36.0
# 3       4      Dodge                   1998        238.0          41.0
# 4       5      Buick                   1996         74.0          98.0
# ..    ...        ...                    ...          ...           ...
# 995   996   Plymouth                   1978        194.0          57.0
# 996   997       Ford                   2003        484.0          45.0
# 997   998  Chevrolet                   2002        237.0          73.0
# 998   999    Lincoln                   2012        332.0          81.0
# 999  1000     Jaguar                   2004        218.0          79.0
#
#        postal_code  claim_amount policy_id  marital_status
# ...

# %%
pd.concat([task1, task2])
# Out:
#        id    car_brand  car_registration_year  car_eng_pow  customer_age  \
# 0       1  Lamborghini                   1992        141.0          18.0
# 1       2   Volkswagen                   1991        363.0          67.0
# 2       3       Nissan                   2003        460.0          32.0
# 3       4          Kia                   2007        221.0          37.0
# 4       5  Lamborghini                   2009        238.0          22.0
# ..    ...          ...                    ...          ...           ...
# 995   996     Plymouth                   1978        194.0          57.0
# 996   997         Ford                   2003        484.0          45.0
# 997   998    Chevrolet                   2002        237.0          73.0
# 998   999      Lincoln                   2012        332.0          81.0
# 999  1000       Jaguar                   2004        218.0          79.0
#
#     postal_code  claim_amount policy_id  marital_status
# ...
